# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data2Pop.csv')

# %%
ncells = df.Cell.unique()
for cell in ncells:
    cell0 = df[df.Cell == cell]
    plt.plot(cell0.Size)

# %%
tmg = 15
cells = 1000

file_on = f'../simulation_data/gillespie/gillespie_on_{tmg}_cells_{cells}.csv'
file_off = f'../simulation_data/gillespie/gillespie_off_{tmg}_cells_{cells}.csv'

data_on = pd.read_csv(file_on, delimiter='|')
data_off = pd.read_csv(file_off, delimiter='|')

# %%
times = data_on.On_Time.unique()

# %%
times_off = data_off[data_off.On_Time>0].On_Time.unique()

# %%
plt.hist(times_off,bins=30, color='green', alpha=0.5);

# %% [markdown]
# Cargar Datos

# %%
import tensorflow as tf

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(imagenes, categorias) = fashion_mnist.load_data()[0]
# Out:
# ...
# 4423680/4422102 [==============================] - 2s 0us/step

# %%
imagenes.shape
# Out:
# (60000, 28, 28)

# %%
imagenes[0].shape, categorias[0]
# Out:
# ((28, 28), 9)
