# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data_off = pd.read_csv(f'../simulation_data/euler/deterministic_steady_state_euler_off.csv', delimiter='|')
data_on = pd.read_csv(f'../simulation_data/euler/deterministic_steady_state_euler_on.csv', delimiter='|')

# %%
time = [i/2 for i in range(120)]
plt.plot(time,data_on.Permease, 'g-',ms=0.8, label='Initial State On')
plt.plot(time,data_off.Permease, 'r--',ms=0.8, label='Initial State Off')
plt.legend(loc=7)
plt.title('Permease Deterministic\nSteady State')
plt.ylabel('Permease Concentration')
plt.xlabel('TMG (µM)')
plt.xlim(0)
plt.ylim(0)
plt.grid()

# %%
time = [i/2 for i in range(120)]
plt.plot(time,data_on.mRNA, 'g-',ms=2, label='Initial State On')
plt.plot(time,data_off.mRNA, 'r--',ms=2, label='Initial State Off')
plt.legend(loc=7)
plt.title('mRNA Deterministic \nSteady State')
plt.ylabel('mRNA Concentration')
plt.xlabel('TMG (µM)')
plt.xlim(0)
plt.ylim(0)
plt.grid()

# %%
time = [i/2 for i in range(120)]
plt.plot(time,data_on.Intracellular_TMG, 'g-',ms=2, label='Initial State On')
plt.plot(time,data_off.Intracellular_TMG, 'r--',ms=2, label='Initial State Off')
plt.legend(loc=7)
plt.title('Intracellular TMG Deterministic \nSteady State')
plt.ylabel('Intracellular TMG Concentration')
plt.xlabel('TMG (µM)')
plt.xlim(0)
plt.ylim(0)
plt.grid()

# %%
time = [i/2 for i in range(120)]
plt.plot(time,data_on.Active_LacI, 'g-',ms=2, label='Initial State On')
plt.plot(time,data_off.Active_LacI, 'r--',ms=2, label='Initial State Off')
plt.legend(loc=7)
plt.title('Active LacI Deterministic \nSteady State')
plt.ylabel('Active LacI Concentration')
plt.xlabel('TMG (µM)')
plt.xlim(0)
plt.ylim(0)
plt.grid()

# %%
time = [i/2 for i in range(120)]
plt.plot(time,data_on.LacI_monomer, 'g-',ms=2, label='Initial State On')
plt.plot(time,data_off.LacI_monomer, 'r--',ms=2, label='Initial State Off')
plt.legend(loc=7)
plt.title('LacI Monomers Deterministic \nSteady State')
plt.ylabel('LacI Monomers Concentration')
plt.xlabel('TMG (µM)')
plt.xlim(0)
plt.ylim(0)
plt.grid()

# %%
time = [i/2 for i in range(120)]
plt.plot(time,data_on.LacI_tetramer, 'g-',ms=2, label='Initial State On')
plt.plot(time,data_off.LacI_tetramer, 'r--',ms=2, label='Initial State Off')
plt.legend(loc=7)
plt.title('LacI Tetramers Deterministic \nSteady State')
plt.ylabel('LacI Tetramers Concentration')
plt.xlabel('TMG (µM)')
plt.xlim(0)
plt.ylim(0)
plt.grid()
